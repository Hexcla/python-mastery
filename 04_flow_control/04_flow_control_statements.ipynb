# %% [markdown]
# # Introduction to Flow Control Statements in Python

# %% [raw]
# 1) The purpose of Flow Control Statements in Python is that " To perform certain Operation(X-Operation in the case of True or Y-Operation of False).
#
# 2) In Python programming, Flow Control Statements are classfiied into 2 Types. They are
#
#                                 a) Conditional Statements.
#                                 b) Looping Statements.

# %% [markdown]
# # Conditional Statements.

# %% [raw]
# 1) In Python Programming, we have 3 Types of Conditional Statements. They are
#                                     a) Simple if statement
#                                     b) if...else statement
#                                     c) if..elif..else statement

# %% [markdown]
# # Simple if statement

# %% [raw]
# if cond:
#     #block of if statement

# %%
if 5<7:
    print("I am in If block.")
    
#print("Program Execution Over")
# Out:
# I am in If block.

# %%
if 5>7:
    print("I am in If block.")
    
#print("Program Execution Over")

# %%
if 5<7:
    d = 5 + 7
    
print(d)
# Out:
# 12

# %%
del d

# %%
if 5>7:
    print("if statement executed")
    
#print("Program executed")

# %%
# WAP if age is greater than or equals 18 then you are eligible for vote.

age = int(input(" enter student age : "))

if age >= 18:
    print("you are eligible for vote")
    
#print("Program executed")
# Out:
# you are eligible for vote

# %%
age = int(input("Enter your age: "))

if age >= 18:
    print("you are eligible for vote")

# %% [markdown]
# # if...else statement

# %% [raw]
# if your cond in true then if block of statement will execute . otherwise your cond is false then execute else part.
#
# if cond:
#     #if block of statement
# else:
#     #else block of statement

# %%
# WAP if age is greater than or equals 18 then you are eligible for vote otherwise not eligible

age = int(input("Enter your age: "))

if age >= 18:
    print("You are eligible for vote")
else:
    print("Not eligible for vote.")
# Out:
# You are eligible for vote

# %% [markdown]
# # if..elif..else statement

# %% [raw]
# syntax:
#
# if cond:
#     #block of code
# elif cond:
#     #block of code
# elif cond:
#     #block of code
# .
# .
# .
# else:
#     #block of code

# %%
# wap, 
# who will keep 90 mark --- A grade   
# who will keep 80 mark --- B grade
# who will keep 70 mark --- C grade
# who will keep 60 mark --- D grade

# %%
mark = int(input("Enter your Mark: "))


if mark >= 90:
    print("A Grade.")
elif mark >=80 and mark < 90:
    print("B Grade.")
elif mark >=70 and mark <80:
    print("C Grade.")
elif mark >=60 and mark < 70:
    print("D Grade")
else:
    print("Fail")
# Out:
# Enter your Mark: 76
# C Grade.

# %%
a = int(input("enter the number :- "))

Lucky_no = 23


if a == Lucky_no:
    print("You're Winner")
else:
    print("Good Luck, try again")
# Out:
# Good Luck, try again

# %%
a = "Python"



if "y" in a:
    print("Y is present")
else:
    print("not  present")
# Out:
# Y is present

# %%
mark = int(input("Enter your Mark: "))


if mark >= 90:
    print("A Grade.")
elif mark >=80:
    print("B Grade.")
elif mark >=70:
    print("C Grade.")
elif mark >=60:
    print("D Grade")
else:
    print("Fail")
# Out:
# Enter your Mark: 76
# C Grade.

# %%
# Write a program to check whether a number is even or odd.

# %%
num = int(input("Enter first number: "))

if num % 2 == 0:
    print("Number is even")
else:
    print("Number is odd")
# Out:
# Enter first number: 550
# Number is even

# %%
267 % 2
# Out:
# 1

# %%
1. Create a program that compares two numbers and prints the larger one using if-else.

# %%
2. Create a program that classifies a given temperature as hot (>30°C), warm (20-30°C), or cold (<20°C) 
using if-elif-else statements.

# %%
3. create a Python program that checks if a given string is a palindrome using if- else statement,  
for string take the input from the user

# %%
4.create a Python program that takes a letter as input & determines if it's vowel or a consontant using if- else

# %% [raw]
# 5.create a Python program that checks the email id is vaild or not
# on the basis of, if your email is contains @ & . then it is vaild
#
# for email - takee the data from user

# %%
email = input("enter the email:- ")


if  email in system_db:
    print("Login successful")
else:
    print("Please check email address")
# Out:
# valid email

# %%
number=int(input('larger number'))

if number >100:
       print('its the larger number')
else:
       print('its smaller number')

# %%
string = input("enter the name :- ")

if string == string[::-1]:
    print("it's palidrome")
else:
    print("not")
# Out:
# enter the name :- gill
# not
