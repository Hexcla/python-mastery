# %% [markdown]
# Decorator in python

# %% [raw]
# - In Python, a decorator is a design pattern that allows you to dynamically alter the functionality of a function, method, or class without directly modifying its code.
# -Decorators are implemented using the "@" symbol
#
# - They are commonly used for adding behavior such as logging, authentication, caching, or performance monitoring to functions or methods.

# %%
def my_decorator(func):
    def wrapper():
        print("Something is happening before the function is called.")
        func()
        print("Something is happening after the function is called.")
    return wrapper

@my_decorator
def say_hello():
    print("Hello!")

say_hello()
# Out:
# Something is happening before the function is called.
# Hello!
# Something is happening after the function is called.

# %%
a=10

# %%
def uppercase_decorator(func):
    def wrapper(text):
        result = func(text)
        return result.upper()
    return wrapper

@uppercase_decorator
def greet(name):
    return f"Hello, {name}!"

greeting = greet("John")
print(greeting)
# Out:
# HELLO, JOHN!

# %% [markdown]
# Iterator

# %% [raw]
# - An iterator in Python is an object that represents a stream of data, allowing you to traverse through a sequence of elements one by one.
# - iterator object must implement two methods:
#
# 1. __iter__(): This method returns the iterator object itself. It is called when the iterator is initialized or when the iter() function is called on the iterator object.
# 2. __next__(): This method returns the next element in the sequence. It is called repeatedly to retrieve each successive element. When there are no more elements to return, it should raise a StopIteration exception.

# %%
my_list = [1, 2, 3, 4, 5]

# Creating an iterator from the list
my_iterator = iter(my_list)

# %%
my_iterator

# %%
for item in my_iterator:
    print(item)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
class MyIterator:
    def __init__(self, max_num):
        self.max_num = max_num
        self.current = 0

    def __iter__(self):
        return self

    def __next__(self):
        if self.current < self.max_num:
            self.current += 1
            return self.current
        else:
            raise StopIteration

# Using the iterator
my_iter = MyIterator(3)

# Accessing elements using the next() method
print(next(my_iter))  
print(next(my_iter))  
print(next(my_iter))
# Out:
# 1
# 2
# 3

# %% [markdown]
# Generator

# %% [raw]
# - A generator in Python is a special type of iterator that generates values on-the-fly.
# -  It allows you to iterate over a sequence of items without the need to store them all in memory at once, which can be very memory-efficient, especially for large datasets.
#
# - Generators are defined using a function that contains one or more yield statements.
# - yield in Python returns a value from a function and temporarily suspends its execution, allowing it to resume from where it left off.

# %%
def my_generator():
    yield 1
    yield 2
    yield 3

gen = my_generator()

print(next(gen))  
print(next(gen))  
print(next(gen))
# Out:
# 1
# 2
# 3

# %% [markdown]
# difference between a generator and an iterator

# %% [raw]
# 1.Generator:
#
# - A generator in Python is a special type of iterator.
# - It is implemented using a function with one or more yield statements.
# - Generators can be created using generator expressions or by defining generator functions.
# - They automatically implement both the iterator protocol (__iter__() and __next__() methods) and manage state internally.
# - Generators generate values lazily, meaning they produce values on-the-fly as requested, saving memory by not storing all values in memory at once.
# - Generators are typically used to create iterators in a more concise and readable manner, especially for large datasets or infinite sequences.

# %% [markdown]
# 2. Iterator:
#
# - An iterator is an object that represents a stream of data.
# - It is implemented using a class that defines the __iter__() and __next__() methods.
# - Iterators can be created explicitly by implementing these methods in a custom class, or they can be created implicitly from iterables using the iter() function.
# - Iterators traverse over a sequence of elements, allowing you to access each element sequentially.
# - Iterators don't maintain internal state automatically; you have to manage state explicitly within the class.
# - Iterators are used to loop over collections like lists, tuples, dictionaries, etc., or to define custom iterable objects.

# %%
for i in range(1,5):
    if i ==3:
        break
    print(i,end=' ')
# Out:
# 1 2

# %%
for i in range(1,5):
    if i ==3:
        continue
        print(i)
    print(i)
# Out:
# 1
# 2
# 4

# %%
for i in range(5):
    if i == 2:
        pass 
        print(i)
    else:
        print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# difference betwwen the pass and continue

# %% [raw]
# - The "continue" statement is used within loops to skip the current iteration and move to the next one.
# When encountered, "continue" causes the program to jump directly to the next iteration of the loop, skipping any remaining code within the loop for the current iteration.
# - pass useful when you want to skip certain conditions or values without exiting the loop entirely.
