# %% [markdown]
# Multiprocessing in Python:

# %% [raw]
# - a program to execute multiple processes concurrently, each with its own memory space and resources.
# - multiprocessing allows multiple independent processes to run simultaneously, making use of multiple CPU cores and potentially improving overall performance.

# %% [markdown]
# Key Concepts of Multiprocessing

# %% [raw]
# - Processes: A process is an instance of a program that is being executed.
# - Multiprocessing Module: The multiprocessing module in Python provides classes and functions to create and manage multiple processes.
# - Parallel Execution
# - Communication Between Processes: Processes can communicate with each other using inter-process communication (IPC) mechanisms such as pipes, queues, shared memory, and synchronization primitives like locks and semaphores.
# - Performance: Multiprocessing can improve the performance of CPU-bound tasks by utilizing multiple CPU cores effectively.

# %% [raw]
# Import the MultiProcessing
#
#                                 import multiprocessing

# %%
import multiprocessing

# %%
# Function to calculate the square of a number
def square(x):
    return x * x

if __name__ == "__main__":
    # Create a multiprocessing Pool with 2 processes
    pool = multiprocessing.Pool(processes=5)

    # List of numbers to square
    numbers = [1, 2, 3, 4, 5]

    # Use the map function to apply the square function to each number in parallel
    results = pool.map(square, numbers)

    # Close the pool to free up resources
    pool.close()
    pool.join()  # Wait for all processes to finish

    # Print the results
    print("Squared numbers:", results)

# %%
difference between multi thread and multi processor

# %%
multi threading

- independent
- it will excuting in single processor.
- internaly comminicate each other.

# %%
multi processor
- dependent
- it will be excuting in multi processor.
- external they goin to communicate like pipes.
