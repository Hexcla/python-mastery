# %% [markdown]
# Hi everyone, I’m Yogendra, a junior Python developer.
# When I began learning Python, the syntax felt overwhelming and confusing. Instead of just memorizing it, I started questioning why things are designed the way they are.
# That curiosity helped me truly understand Python and develop a strong interest in it.
#
# This repository, "python-for-beginners", is created to share that understanding in a simple and beginner-friendly way.|

# %% [markdown]
# 1. Start from real life
#
# In real life, you don’t just have data—you do things with it.
# You have numbers → you add, subtract
# You have text → you combine, compare
# You have decisions → you check conditions
#
# Example:
#
# Money → you add income, subtract expenses
# Age → you check age > 18
# Name → you compare "Yogendra" == input_name
# So operations are just actions on data.

# %% [markdown]
# # What is python

# %% [raw]
# Python is one of the General purpose programming language.
# python developed by "Guido Van Rossum" and officially released in 1991 feb 20.

# %% [markdown]
# # Where can we use Python?

# %% [raw]
# # 1. Web application development
# 2. Gaming application
# 3. Data science
# 4. data analyst
# 5. AI Application
# 6. Automation & testing
# .
# .
# . etc

# %% [markdown]
# # What is the features in Python?

# %% [raw]
# 1. simple & easy to learn
# 2. open source
# 3. platform independent lang
# 4. Dynamically type language
# 5. supports third party libraries (numpy, pandas, seaborn.... etc)

# %% [markdown]
# # Comments

# %% [raw]
# #single line comment
#
# # python program 1

# %%
#python first program

# program 2
# progar 3

# %%
#mutli line comments

"""
my python
fwrrefer
fweferf
rfr
rferferfer
ferferfe

"""


'''
welcome 
to python

'''

# %% [markdown]
# # variable

# %% [raw]
# variable is like a container, which stores some values.

# %% [markdown]
# # rules for creating variable

# %% [raw]
# 1. a variable name is a combination of alphabets, digits, and a special symbol called underscore(_).

# %% [raw]
# 2. The first letter of variable name must starts with an alphabet or underscore(_) symbol.

# %% [raw]
# 3. in symbols, we can use only underscore(_) symbol.

# %% [raw]
# 4. we can't use keywords for creating variable

# %% [raw]
# a  = 0

# %% [raw]
# 5. all variable names are case sensitive

# %% [raw]
# print() = 10

# %%
# Case Sensitive

a = 10

A = 20

# %%
print(A)
# Out:
# 20

# %%
# name 'a1_' is not defined -  variable is not created


print(ab)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 # name 'a1_' is not defined -  variable is not created
# ----> 4 print(ab)
#
# NameError: name 'ab' is not defined

# %%
a = 10
a

# %%
_a = 5
print(_a)
# Out:
# 5

# %%
7gfgf = 7
# Out:
#   Cell In[7], line 1
#     7gfgf = 7
#      ^
# SyntaxError: invalid syntax

# %%
for = 10
# Out:
#   Cell In[9], line 1
#     for = 10
#         ^
# SyntaxError: invalid syntax

# %%
else = 23
# Out:
#   Cell In[10], line 1
#     else = 23
#     ^
# SyntaxError: invalid syntax

# %%
a=10

# %%
print(a)

# %%
print(A)

# %%
# ID 

a = 1
b = 2

#print(a)

# id() - to check the id of any variable

print(id(a))
print(id(b))
# Out:
# 140712565942048
# 140712565942080

# %% [markdown]
# # Data types

# %% [raw]
# In python.
#
# 1. int == Interger
# 2. float -- decimal
# 3. bool - Ture or false or 0,1
# 4. str -- "String", 'String'
# 5. range -- It is used to tell about limit
#
# collections data type
#
# 6. list --  []
# 7. tuple
# 8. dict
# 9. set
# 10.frozenset
# 11.None

# %% [markdown]
# # int

# %%
a = 756
b = 20

# type() - to check the datatype of any variable

print(type(a))

#print(a)
# Out:
# <class 'int'>

# %% [markdown]
# # float

# %%
a = 10.25

print(type(a))
# Out:
# <class 'float'>

# %% [markdown]
# # bool

# %% [raw]
# To store True & False value
# Internally True=1, False =0.

# %%
a = True  #internally True = 1


print(type(a))
# Out:
# <class 'bool'>

# %%
b = False    #internally False=0

print(type(b))
# Out:
# <class 'bool'>

# %%
c = true


type(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 c = true
#       4 type(c)
#
# NameError: name 'true' is not defined

# %%
print(a+a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(a+a)
#
# NameError: name 'a' is not defined

# %%
print(a+b)
# Out:
# 1

# %%
a+a  #1+1
# Out:
# 2

# %%
b+b  #0+0
# Out:
# 0

# %% [markdown]
# # str

# %% [raw]
# To store string data, text data, alphanumeric data, numeric data, any type data within
# single quotes,
# double qoutes,
# triple single quotes and
# triple double qoutes./

# %%
a = 'python6668^&*%^&'

print(type(a))
# Out:
# <class 'str'>

# %%
a = "python"

print(a, type(a))
# Out:
# python <class 'str'>

# %%
a = '''python'''

print(a, type(a))
# Out:
# python <class 'str'>

# %%
a = """python"""
print(a, type(a))
# Out:
# python <class 'str'>

# %%
In python, we have two types of string data

        1. single line string data
        2. multi line string data

# %%
a = 'welcome
to
python 
programming
world'

print(type(a))
# Out:
#   Cell In[35], line 1
#     a = 'welcome
#                 ^
# SyntaxError: EOL while scanning string literal

# %%
a= "welcome
to
python 
programming
world"

print(a, type(a))
# Out:
#   Cell In[36], line 1
#     a= "welcome
#                ^
# SyntaxError: EOL while scanning string literal

# %%
a = '''welcome
to
python 
programming
world'''
print(type(a))

print(a)
# Out:
# <class 'str'>
# welcome
# to
# python
# programming
# world

# %%
a= """welcome
to
python 
programming
world"""
print(a, type(a))
# Out:
# welcome
# to
# python
# programming
# world <class 'str'>

# %%
print(a,type(a))

# %% [markdown]
# # type casting

# %% [raw]
# convert from one data type to another data type

# %%
a = 10

print(a,type(a))
# Out:
# 10 <class 'int'>

# %%
# convert integer to float

a = float(a)

print(a,type(a))
# Out:
# 10.0 <class 'float'>

# %%
#convert integer to bool

# %%
a = 0

print(a, type(a))
# Out:
# 0 <class 'int'>

# %%
b = bool(a)

print(b,type(b))
# Out:
# False <class 'bool'>

# %%
#int to str

# %%
a= 10

b = str(a)

print(b)


print(type(b))
# Out:
# 10
# <class 'str'>

# %%
b
# Out:
# '10'

# %%
#float to other data types

# %%
a = 10.90

print(a, type(a))
# Out:
# 10.9 <class 'float'>

# %%
#float to int

b = int(a)

print(b,type(b))
# Out:
# 10 <class 'int'>

# %%
#float to bool

a = 0.0

b= bool(a)

print(b, type(b))
# Out:
# True <class 'bool'>

# %%
b=bool(a)

# %%
print(b,type(b))

# %%
a= 0.0
print(a,type(a))

# %%
b=bool(a)
print(b,type(b))

# %%
#float to str

a = 20.78

print(a, type(a))
# Out:
# 20.78 <class 'float'>

# %%
b = str(a)
print(b,type(b))
# Out:
# 20.78 <class 'str'>

# %%
b
# Out:
# '20.78'

# %% [raw]
# #assignment
# type casting
#
# bool to int
# bool to float
# bool to str

# %%
#string to other data types

# %%
a = '10.5'

b = float(a)


print(b,type(b))
# Out:
# 10.5 <class 'float'>

# %%
a = '10'     #numerical string

print(a,type(a))
# Out:
# 10 <class 'str'>

# %%
b = int(a)

print(b,type(b))
# Out:
# 10 <class 'int'>

# %%
a='python'  

print(a,type(a))
# Out:
# python <class 'str'>

# %%
b=int(a)

print(b,type(b))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 b=int(a)
#       3 print(b,type(b))
#
# ValueError: invalid literal for int() with base 10: 'python'

# %%
#str to float
a='10.25'          #floating string
print(a,type(a))

# %%
b=float(a)
print(b,type(b))

# %%
a='python'     
b=float(a)
print(b,type(b))

# %%
#string to bool

a = "python"

print(a,type(a))
# Out:
# python <class 'str'>

# %%
b = bool(a)


print(b,type(b))
# Out:
# True <class 'bool'>

# %%
# empty string

a = ""
print(a,type(a))
# Out:
#  <class 'str'>

# %%
b=bool(a)

print(b,type(b))
# Out:
# False <class 'bool'>

# %%
a= '0'
print(a,type(a))
# Out:
# 0 <class 'str'>

# %%
b=bool(a)
print(b,type(b))
# Out:
# True <class 'bool'>

# %% [markdown]
# # Pre-defined methods/function in string

# %% [raw]
# #1. capitalize()
# #2. title()
# #3. swapcase() # it will convert from lower case to uppercase or viseversa
# #4. upper()
# #5  lower()
# #6. islower()
# #7. isupper()
# #8. isdigit() - to check number in the string
# #9. isalpha() - to check characters in string
# #10. isalnum() - # to check number & characters in the string
# #11 isspace()
# #12. split()   # by defaut it will take space
# #13. count() # for counting the spaces or any letters
#
# len()

# %%
a = 'python is the programming language'

a = a.capitalize()

#print(b)
print(a)
# Out:
# Python is the programming language

# %%
a = "python,is a programming language."

a.capitalize()
# Out:
# 'Python,is a programming language.'

# %%
# title() -  #first letter captial for all the words

# %%
a = "python,is a programming language."

a = a.title()


print(a)
# Out:
# Python,Is A Programming Language.

# %%
#3. swapcase # it will convert from lower case to uppercase or viseversa

# %%
a = "Python"

a.swapcase()
# Out:
# 'pYTHON'

# %%
a = "PYTHON"

a.swapcase()
# Out:
# 'python'

# %%
a="PytHOn"

a.swapcase()
# Out:
# 'pYThoN'

# %%
#4. upper

a = "PytHOn"

a.upper()
# Out:
# 'PYTHON'

# %%
#5 lower

a="PytHOn"

a.lower()
# Out:
# 'python'

# %%
#6. islower()

a = 'python'

b = a.islower()

print(b)
# Out:
# True

# %%
a = 'pyThon'

print(a.islower())

#print(a)
# Out:
# False

# %%
#7. isupper()

a = 'PYTHON'

print(a.isupper())
# Out:
# True

# %%
a='PyTHON'

a.isupper()
# Out:
# False

# %%
#8. isdigit() - to check number in the string

a = "67"


a.isdigit()
# Out:
# True

# %%
a = "1234 "

a.isdigit()
# Out:
# False

# %%
a = "python1234"

a.isdigit()
# Out:
# False

# %%
#9. isalpha() - to check characters in string

a = "Python"

a.isalpha()
# Out:
# False

# %%
a = "python1234"

a.isalpha()
# Out:
# False

# %%
#10. isalnum() - # to check number & characters in the string

a = "python1234"

a.isalnum()
# Out:
# True

# %%
a = "python"  # if character is there also, it will show true

a.isalnum()
# Out:
# True

# %%
a = "1234"
a.isalnum()
# Out:
# True

# %%
a = "python 1234"

a.isalnum()
# Out:
# False

# %%
#11 isspace()

a = " "

print(a.isspace())
print(type(a))
# Out:
# True
# <class 'str'>

# %%
print(a)

# %%
a = ""

print(a.isspace())
print(type(a))
# Out:
# False
# <class 'str'>

# %%
a = "  "

a.isspace()
# Out:
# True

# %%
a = " "

print(a.isspace())
print(type(a))
# Out:
# True
# <class 'str'>

# %%
#12. split()   # by defaut it will take space 

a = "python is a prog lang"

b = a.split()

print(b)

print(type(b))
# Out:
# ['python', 'is', 'a', 'prog', 'lang']
# <class 'list'>

# %%
a= "python is a prog lang"
type(a)

# %%
#13. count() # for counting the spaces or any letters

a = "python is a prog lang"

b = a.count(" ")   

print(b)
# Out:
# 4

# %%
# find the length of the string

len(a)
# Out:
# 21

# %%
a  = "Pythoon"

a.count(" ")
# Out:
# 2

# %%
a = "python is a prog"
a.count(" ")
# Out:
# 3

# %% [markdown]
# # Indexing and slicing in String

# %%
postive index will start from left side - 0,1,2,3

# %%
A=[1,2,3,4,5]
pa=0,1,2,3,4
ng=-4,-3,-2,-1
{}

# %%
s = "PYTHON"

# %%
#index

s[2]
# Out:
# 'T'

# %%
s[0]
# Out:
# 'P'

# %%
s[-1]
# Out:
# 'N'

# %%
s="PYTHON"     #sub string of a string

# %%
len(s)
# Out:
# 6

# %% [markdown]
# s = "PYTHON"
#      012345

# %%
# slicing
# [starting no, ending no, step value]

s = "PYTHON"

s[1:4]
# Out:
# 'YTH'

# %%
s[0:4]     #0,1,2,3  ---> pyth
# Out:
# 'PYTH'

# %%
s[2:]
# Out:
# 'THON'

# %%
s[3:4]
# Out:
# 'H'

# %%
s="PYTHON"

# %% [markdown]
# s = "PYTHON"
#      012345

# %%
#slicing


# [starting no, ending no, step value]


s="PYTHON"

s[0:6:1]    #0,1 = 1
# Out:
# 'PYTHON'

# %%
s[:3]
# Out:
# 'PYT'

# %%
s[2:]
# Out:
# 'THON'

# %%
s=[:]
# Out:
#   Cell In[39], line 1
#     s=[:]
#        ^
# SyntaxError: invalid syntax

# %%
s[0:6:1]
# Out:
# 'PYTHON'

# %%
s[0:6:2]
# Out:
# 'PTO'

# %% [markdown]
#     -6,-5,-4,-3,-2,-1,
# s = "PYTHON"
#      012345

# %%
Neative slicing

# %%
s="PYTHON"


s[-4:]
# Out:
# 'THON'

# %%
s[::-1]
# Out:
# 'NOHTYP'

# %%
s[-1:-6:-2]
# Out:
# 'NHY'

# %%
s[-1:-5:-2]
# Out:
# 'NH'

# %%
s[-5:-1]
# Out:
# 'YTHO'

# %%
s[2:4]    #2,3

# %%
#how to check length of string--- By using len()

len(s)
# Out:
# 6

# %%
s="PYTHON" 

s[0:100]
# Out:
# 'PYTHON'

# %%
s[0:]

# %%
s[1:]

# %%
s[:4]

# %%
s = "abcdefghijk"

len(s)

# %%
s[5:12]

# %%
s[0:12:1]

# %%
s[0:12:2]

# %%
s[0:11:3]

# %%
#reverse a string

# %%
s
# Out:
# 'PYTHON'

# %%
s[:]
# Out:
# 'PYTHON'

# %%
s[::]
# Out:
# 'PYTHON'

# %%
s[::2]
# Out:
# 'PTO'

# %%
#reverse a string

s[::-1]
# Out:
# 'NOHTYP'

# %%
s[::-2]
# Out:
# 'NHY'
